# %% [markdown]
# <a href="https://colab.research.google.com/github/lakhbir-05/Thapar-Summer-School-2025-/blob/main/Copy_of_Linear_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# **2. Creating random dataset**

# %%
X = np.random.rand(20).reshape(-1,1)
Y = np.random.rand(20)

print("X = ", X)
print("\nY = ", Y)
# Out:
# X =  [[0.4294462 ]
#  [0.14722943]
#  [0.95636981]
#  [0.08740177]
#  [0.36650103]
#  [0.817114  ]
#  [0.28197968]
#  [0.18071247]
#  [0.65372549]
#  [0.97759308]
#  [0.66332175]
#  [0.06454982]
#  [0.0347903 ]
#  [0.14106388]
#  [0.79175783]
#  [0.01983565]
#  [0.60510304]
#  [0.34673801]
#  [0.58256598]
#  [0.34052628]]
#
# Y =  [0.32006464 0.35631014 0.67540745 0.3749479  0.37832065 0.73847847
#  0.38194057 0.08283177 0.3765095  0.63667903 0.52268242 0.30553106
#  0.74967657 0.53213453 0.51513447 0.42389494 0.81200981 0.66542249
#  0.40641589 0.07744984]

# %% [markdown]
# **3. Splitting data into train and test dataset**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 20 )

print("X_train",X_train)

print("\nX_test",X_test)

print("\nY_train",Y_train)

print("\nY_test",Y_test)
# Out:
# X_train [[0.34673801]
#  [0.0347903 ]
#  [0.34052628]
#  [0.817114  ]
#  [0.65372549]
#  [0.58256598]
#  [0.4294462 ]
#  [0.95636981]
#  [0.18071247]
#  [0.28197968]
#  [0.06454982]
#  [0.97759308]
#  [0.01983565]
#  [0.08740177]]
#
# X_test [[0.60510304]
#  [0.14106388]
#  [0.66332175]
#  [0.36650103]
#  [0.14722943]
#  [0.79175783]]
#
# Y_train [0.66542249 0.74967657 0.07744984 0.73847847 0.3765095  0.40641589
#  0.32006464 0.67540745 0.08283177 0.38194057 0.30553106 0.63667903
#  0.42389494 0.3749479 ]
#
# Y_test [0.81200981 0.53213453 0.52268242 0.37832065 0.35631014 0.51513447]

# %% [markdown]
# **4. Creating an instance for the linear regression model**

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %% [markdown]
# **5. Creating/Train Linear Model**

# %%
# Training the model by passing the dependent and independent features of the training dataset
lr.fit(X_train, Y_train)
lr
# Out:
# LinearRegression()

# %% [markdown]
# **6. Make prediction on test dataset**

# %%
Y_pred = lr.predict( X_test)

print(Y_pred)
# Out:
# [0.49583515 0.37089602 0.51151011 0.43159332 0.37255605 0.54609058]

# %% [markdown]
# **7. Model Evaluation**

# %% [markdown]
# **7.1 Get the coefficients**

# %%
# The value of the coefficients for the independent feature through the multiple regression model
print("Value of the oefficients: \n", lr.coef_)
# Out:
# Value of the oefficients:
#  [0.26924264]

# %% [markdown]
# **7.2 Get Mean squared error between Actual and Predicted**

# %%
# The value of the mean squared error
print(f"Mean square error: {mean_squared_error( Y_test, Y_pred)}")
# Out:
# Mean square error: 0.02169154662757086

# %% [markdown]
# **7.3 Get R Square between Actual and Predicted**

# %%
# The value of the coefficient of determination, i.e., R-square score of the model
print(f"Coefficient of determination: {r2_score( Y_test, Y_pred )}")
# Out:
# Coefficient of determination: 0.016355401495154798

# %% [markdown]
# **7.4 Scatter Plot**

# %%
# Plotting the output
plt.scatter(X_test, Y_test, color = "black", label = "original data")
plt.plot(X_test, Y_pred, color = "blue", linewidth=3, label = "regression line")
plt.xlabel("Independent Feature")
plt.ylabel("Target Values")
plt.title("Simple Linear Regression")
plt.show()
