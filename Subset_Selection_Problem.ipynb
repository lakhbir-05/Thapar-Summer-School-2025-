# %% [markdown]
# <a href="https://colab.research.google.com/github/lakhbir-05/Thapar-Summer-School-2025-/blob/main/Subset_Selection_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Subset Selection Problem**

# %% [markdown]
# 1. Problem Statement:
#
# Find all the subsets from a set of numbers whose sum is zero.
#
# Constraint: Subset size must be 5
#
# Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}

# %%
#-------------------------------------------------------------
# Step 1: Library inclusion
#-------------------------------------------------------------
import random as rnd


#-------------------------------------------------------------
# Step 2: Parameter Setting
#-------------------------------------------------------------
Set         = set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
SetSize     = 5
ResultList  = set()    # Store Result List i.e. list of sets whose sum is zero
Iterations  = 1000   # Number of Inerations


#-------------------------------------------------------------
# Step3: Start Program
#-------------------------------------------------------------

# Convert the set to a list for random.sample()
SetAsList = list(Set)

# Loop till number of Iterations
for i in range(Iterations):
    # Select number of elements from Set
    Chromosome = rnd.sample(SetAsList,SetSize)

    # Sum the number of elements in the Chromosome
    if sum(Chromosome) == 0:
        ResultList.add(tuple(Chromosome))

# Print all the sets whose sum is zero
for r in ResultList:
        print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList))
# Out:
# (-2, -9, 7, 1, 3)
# (-8, 7, 11, -6, -4)
# (-2, -3, 7, 2, -4)
# (-6, -8, 6, 1, 7)
# (-8, 6, 1, 7, -6)
# (7, -12, 3, -9, 11)
# (-4, 9, 3, -2, -6)
# (-6, -7, -4, 11, 6)
# (2, 7, -9, -6, 6)
# (9, 7, -5, -7, -4)
# (2, -7, 3, 7, -5)
# (-8, -5, 9, 7, -3)
# (-3, 2, 3, 6, -8)
# (-6, -12, -2, 9, 11)
# (6, 11, -4, -8, -5)
# (-3, -8, -2, 6, 7)
# (-7, 7, -4, -2, 6)
# (11, 2, 1, -9, -5)
# (6, -3, -2, 3, -4)
# (-3, 6, 3, -4, -2)
# (-2, 1, -7, 6, 2)
# (1, -4, 11, -5, -3)
# (-2, 11, -7, -8, 6)
# (-8, 3, 6, 11, -12)
# (-3, 1, -12, 3, 11)
# (-8, 11, 6, -6, -3)
# (11, -2, -4, 7, -12)
# (-8, 1, 9, 2, -4)
# (-8, 6, -3, 2, 3)
# (3, -6, 1, 11, -9)
# (-8, 7, -2, 2, 1)
# (3, 7, 1, -7, -4)
# (-6, -8, 11, -4, 7)
#
# Total Sets:  33

# %% [markdown]
# 2. Problem Statement:
#
# Find all the subsets from a set of numbers whose sum is zero.
#
# Constraint: Subset size must be 3 to 6 only
#
# Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}

# %%
#-------------------------------------------------------------
# Step 1: Library inclusion
#-------------------------------------------------------------
import random as r


#-------------------------------------------------------------
# Step 2: Parameter Setting
#-------------------------------------------------------------
Set         = set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
SetLB       = 3
SetUB       = 6
ResultList  = set()    # Store Result List i.e. list of sets whose sum is zero
Iterations  = 1000   # Number of Inerations


#-------------------------------------------------------------
# Step3: Start Program
#-------------------------------------------------------------

# Convert the set to a list for random.sample()
SetAsList = list(Set)

# Loop till number of Iterations
for i in range(Iterations):
    # Select set size randomly
    SetSize = r.randint(SetLB,SetUB)

    # Select number of elements from SetAsList
    Chromosome = r.sample(SetAsList,SetSize)
    Chromosome.sort()

    # Sum the number of elements in the Chromosome
    if sum(Chromosome) == 0:
        ResultList.add(tuple(Chromosome))

# Print all the sets whose sum is zero
for r in ResultList:
        print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList))
# Out:
# (-9, -2, 11)
# (-9, -8, 1, 7, 9)
# (-4, 1, 3)
# (-9, -4, -3, 7, 9)
# (-7, -4, -3, 3, 11)
# (-9, -6, -3, 3, 6, 9)
# (-9, -3, 3, 9)
# (-12, -5, 1, 7, 9)
# (-5, -2, 7)
# (-6, -4, -3, 6, 7)
# (-8, -7, -5, 9, 11)
# (-8, -6, -2, 2, 3, 11)
# (-12, 3, 9)
# (-8, 2, 6)
# (-3, 1, 2)
# (-7, -4, 11)
#
# Total Sets:  16
